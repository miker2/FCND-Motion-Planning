# %%
import pkg_resources
try:
    pkg_resources.require("networkx==2.1")
    import networkx as nx
except:
    import sys
    # !{sys.executable} -m pip install -I networkx==2.1
    pkg_resources.require("networkx==2.1")
    import networkx as nx

# %%
from prm import ProbabilisticRoadMap
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize'] = 20, 20

# %%
# This is the same obstacle data from the previous lesson.
filename = 'colliders.csv'
data = np.loadtxt(filename, delimiter=',', dtype='Float64', skiprows=2)
print(data)
# Out:
# [[-310.2389   -439.2315     85.5         5.          5.         85.5     ]
#  [-300.2389   -439.2315     85.5         5.          5.         85.5     ]
#  [-290.2389   -439.2315     85.5         5.          5.         85.5     ]
#  ...
#  [ 257.8061    425.1645      1.75852     1.292725    1.292725    1.944791]
#  [ 293.9967    368.3391      3.557666    1.129456    1.129456    3.667319]
#  [ 281.5162    354.4156      4.999351    1.053772    1.053772    4.950246]]

# %%
prm = ProbabilisticRoadMap(data, num_samples=2000, zmin=5, zmax=10)
# Out:
# Collision checking took 0.1629650592803955 seconds ...
# Kept 2000 of 2000 points
# Average node coverage area: 423.2
# Grid center: (144.7611, 15.768500000000017)
# Sample point center: ([144.32490859  15.14591198  34.75035384])
# Recommended search radius: 100.3426770082679
# Graph creation took 2.3340489864349365 seconds ...
# Graph has 3477 edges.

# %%
#start = list(prm._graph.nodes)[20]
#find_goal = True
#while find_goal:
#    k = np.random.randint(len(prm._graph.nodes))
#    print(k, len(prm._graph.nodes))
#    goal = list(prm._graph.nodes)[k]
#    if goal[2] == start[2]:
#        find_goal = False
start = (0.14018425345420837, 0.0069622318260371685, 0.0)
goal = (-42.43583077099174, -111.37325211940333, 0.0)

print("start: {}".format(start))
print("goal:  {}".format(goal))
# Out:
# start: (0.14018425345420837, 0.0069622318260371685, 0.0)
# goal:  (-42.43583077099174, -111.37325211940333, 0.0)

# %%
path = prm.plan_path(start, goal)
# Out:
# Adding starting edge to graph: (0.14018425345420837, 0.0069622318260371685, 0.0) <-> (-12.914681250000001, 4.200141518061287, 6.7056000000000004)
# Adding goal edge to graph: (-35.8248375, -106.8560999085505, 6.8976) <-> (-42.43583077099174, -111.37325211940333, 0.0)
# Found a path.
# 11 [(0.14018425345420837, 0.0069622318260371685, 0.0), (-12.914681250000001, 4.200141518061287, 6.7056000000000004), (-18.30530625, -5.895880429812507, 9.1632), (-34.47718125, -26.087924325560095, 8.433599999999998), (-33.129525, -53.01064951989025, 5.976), (-68.1685875, -46.27996822130768, 7.0896), (-60.08265, -73.20269341563784, 6.168), (-64.12561875, -100.125418609968, 9.1248), (-53.34436875, -120.31746250571558, 5.5152), (-35.8248375, -106.8560999085505, 6.8976), (-42.43583077099174, -111.37325211940333, 0.0)]

# %%
fig = plt.figure()

from planning_utils import create_grid
grid, _ = create_grid(data, 1, 1)
plt.imshow(grid, cmap='Greys', origin='lower')

# Add code to visualize path here
nmin = np.min(data[:, 0])
emin = np.min(data[:, 1])

# draw nodes
for n1 in prm._graph.nodes:
    plt.scatter(n1[1] - emin, n1[0] - nmin, c='red')
    
# draw edges
for (n1, n2) in prm._graph.edges:
    plt.plot([n1[1] - emin, n2[1] - emin], [n1[0] - nmin, n2[0] - nmin], 'blue')
    
# TODO: add code to visualize the path
path_pairs = zip(path[:-1], path[1:])
for (n1, n2) in path_pairs:
    plt.plot([n1[1] - emin, n2[1] - emin], 
             [n1[0] - nmin, n2[0] - nmin], 
             'cyan', linewidth=3)


plt.xlabel('NORTH')
plt.ylabel('EAST')
axis_offset = 5
plt.axis([-axis_offset, prm._cdata.xrange + axis_offset, 
          -axis_offset, prm._cdata.yrange + axis_offset])

plt.show()
